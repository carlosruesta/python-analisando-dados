# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosruesta/python-analisando-dados/blob/master/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

dados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true', compression='zip')

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo']
# Out:
# 0        24
# 1        72
# 2        48
# 3        48
# 4        72
#          ..
# 23809    24
# 23810    24
# 23811    48
# 23812    24
# 23813    72
# Name: tempo, Length: 23814, dtype: int64

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# d532d49de       1
# 3e7f719a5       1
# b6b4f212d       1
# 7a2ea4684       1
# 89ced6383       1
# Name: droga, Length: 3289, dtype: int64

# %%
dados['g-0']
# Out:
# 0        1.0620
# 1        0.0743
# 2        0.6280
# 3       -0.5138
# 4       -0.3254
#           ...
# 23809    0.1394
# 23810   -1.3260
# 23811    0.3942
# 23812    0.6660
# 23813   -0.8598
# Name: g-0, Length: 23814, dtype: float64

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# #Desafio 01
# Investigar por que o tratamento está tão desbalanceada
#
# #Desafio 02
# Como plotar as 5 ultimas linhas da tabelona
#
# ###Desafio 03
# Proporção da classe tratamento
#
# ###Desafio 04
# Quantos tipos de drogras foram investigadas?
#
# ###Desafio 05
# Procurar na documentação o método query(pandas)
#
# ###Desafio 06
# Renomear as colunas que tem os hífens
#
# ###Desafio 07
# Deixar os gráficos bonitões(Matplotlib.pyplot)
#
# ###Desafio 08
# Resumo

# %%
# Renomear as colunas g-x e c-x para gx e cx respectivamente
dados.columns= dados.columns.str.replace('-','',regex=True)

# renomeando a coluna droga par composto
mapa = {'droga':'composto'}
dados.rename(columns = mapa, inplace=True)

# %%
dados['tempo'].value_counts().plot.bar()

# %%
# proporção das doses aplicadas
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
# proporção percentual dos valores valores
dados['dose'].value_counts(normalize=True) * 100
# Out:
# D1    51.007811
# D2    48.992189
# Name: dose, dtype: float64

# %%
# proporção dos valores valores
(dados['dose'].value_counts(normalize=True) * 100).plot.pie()

# %%
# Quantas drogas foram aplicadas no estudo?
dados['composto'].nunique()
# Out:
# 3289

# %%
# Quais drogas foram aplicadas?
dados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# d532d49de       1
# 3e7f719a5       1
# b6b4f212d       1
# 7a2ea4684       1
# 89ced6383       1
# Name: composto, Length: 3289, dtype: int64

# %%
## Desafio 1: Investigar por que a a classe tratamento é tão desbalanceada? ##
dados['tratamento'].value_counts().plot.bar(figsize=(5,5),title='Tratamentos aplicados')

# %%
# proporção dos tratamentos aplicados
(dados['tratamento'].value_counts(normalize=True) * 100).plot.pie(figsize=(5,5),title='Tratamentos aplicados')

# %%
# Desafio 4: Quantos tipos de drogas analisadas
dados['composto'].nunique()

# tambem poderia ser:
(dados['composto'].value_counts()).size

# ou
(dados['composto'].unique()).size
# Out:
# 3289

# %%
dados.query('composto=="87d714366"', inplace = False)
# Out:
#                  id tratamento  tempo dose  ...     c96    c97    c98    c99
# 16     id_002fb9c19  com_droga     48   D1  ...  -9.984 -9.984 -9.984 -6.784
# 76     id_00cf039a7  com_droga     48   D2  ... -10.000 -7.436 -6.918 -5.235
# 119    id_01534c4ee  com_droga     72   D2  ... -10.000 -8.771 -9.694 -5.548
# 209    id_0236e3425  com_droga     72   D1  ... -10.000 -8.559 -8.025 -6.642
# 218    id_024a52260  com_droga     24   D2  ...  -7.430 -5.861 -4.591 -3.533
# ...             ...        ...    ...  ...  ...     ...    ...    ...    ...
# 23680  id_fe8abffe0  com_droga     72   D1  ...  -9.910 -8.830 -9.910 -7.807
# 23727  id_ff1d43f96  com_droga     24   D2  ...  -6.896 -5.001 -4.139 -3.271
# 23776  id_ff9d0a022  com_droga     24   D2  ...  -7.529 -6.318 -5.701 -3.561
# 23791  id_ffd1fd119  com_droga     72   D2  ...  -9.966 -8.642 -9.966 -4.605
# 23802  id_fff3976bd  com_droga     24   D1  ...  -8.448 -4.455 -5.793 -3.700
#
# [718 rows x 877 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# pegar os codigos dos primeros 5 compostos com maior número de aplicações
compostoIdList = dados['composto'].value_counts().index[0:5]

# apresentar graficamente os dados usando o Seaborn
plt.figure(figsize=(10,8))
ax = sns.countplot(x='composto', data=dados.query('composto in @compostoIdList'), order=compostoIdList)
ax.set_title('Top 5 compostos',fontsize=15, fontweight='bold')
ax.set_xlabel("Composto",fontsize=12, fontweight='bold')
ax.set_ylabel("Contagem",fontsize=12, fontweight='bold')
plt.show()

# %%
## Vamos analisar os dados do g0. Comosão valores continuos faremos um histogramas com ranges
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g0', 'g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:, 'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:, 'g0':'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
dados.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:, 'g0':'g771'].describe().T['min'].hist(bins=50)

# %%
dados.loc[:, 'g0':'g771'].describe().T['max'].hist(bins=50)

# %%
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='g0' , data=dados)

# %%
dados.loc[:, 'c0':'c99'].describe().T
# Out:
#        count      mean       std   min       25%      50%       75%    max
# c0   23814.0 -0.355156  1.752565 -10.0 -0.549300 -0.00900  0.448975  3.365
# c1   23814.0 -0.455359  2.004962 -10.0 -0.538425  0.00980  0.476875  3.915
# c2   23814.0 -0.480542  2.039346 -10.0 -0.550375 -0.00400  0.460575  2.970
# c3   23814.0 -0.377666  1.554583 -10.0 -0.601975 -0.03905  0.413100  2.408
# c4   23814.0 -0.493552  2.091888 -10.0 -0.559975  0.01140  0.470300  4.555
# ..       ...       ...       ...   ...       ...      ...       ...    ...
# c95  23814.0 -0.353726  1.629291 -10.0 -0.567975 -0.01025  0.444750  2.814
# c96  23814.0 -0.463485  2.059725 -10.0 -0.552575 -0.00125  0.465225  3.505
# c97  23814.0 -0.378241  1.703615 -10.0 -0.561000 -0.00680  0.446400  2.924
# c98  23814.0 -0.470252  1.834828 -10.0 -0.592600  0.01400  0.461275  3.111
# c99  23814.0 -0.301505  1.407918 -10.0 -0.562900 -0.01950  0.438650  3.805
#
# [100 rows x 8 columns]

# %%
sns.boxplot(x='g0', y='tratamento' , data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g0', x='tratamento' , data=dados)
plt.show()

# %%
sns.boxplot(y='g0', x='tratamento' , data=dados)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sns.histplot(dados, x="g0", color='red', ax=axs[0], kde=True)
sns.histplot(dados, x="g1", color = 'blue', ax=axs[1], kde=True)

# %%
# Histogramas dos G's: média, mínimo e máximo
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
sns.histplot(dados.loc[:,'g0':'g771'].describe().T, x="mean", color='red', bins=70, ax=axs[0], kde=True)
sns.histplot(dados.loc[:,'g0':'g771'].describe().T, x="min", color = 'blue', bins=35, ax=axs[1], kde=True)
sns.histplot(dados.loc[:,'g0':'g771'].describe().T, x="max", color = 'blue', bins=35, ax=axs[2], kde=True)

# %%
# boxplot dos g-0 a g-8.  
fig, axs = plt.subplots(3, 3, figsize=(15, 15))
sns.boxplot(y='g0', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[0,0])
sns.boxplot(y='g1', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[0,1])
sns.boxplot(y='g2', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[0,2])
sns.boxplot(y='g3', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[1,0])
sns.boxplot(y='g4', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[1,1])
sns.boxplot(y='g5', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[1,2])
sns.boxplot(y='g6', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[2,0])
sns.boxplot(y='g7', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[2,1])
sns.boxplot(y='g8', x='composto' , data=dados.query('tempo ==72 & composto in ["cacb2b860","87d714366"]'), ax=axs[2,2])

# %% [markdown]
# # Aula 03

# %%
# quantos experimentos por tipo de composto foram aplicados com controle
dados[dados['tratamento'] == 'com_controle'].composto.value_counts()
# Out:
# cacb2b860    1866
# Name: composto, dtype: int64

# %%
# quantos experimentos por tipo de composto foram aplicados com droga
dados[dados['tratamento'] == 'com_droga'].composto.value_counts()
# Out:
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# a9bc2c549      1
# 828099693      1
# e3e768009      1
# 0dedfb162      1
# e68b58a8f      1
# Name: composto, Length: 3288, dtype: int64

# %%
# quantas vezes foram expostos à dose D1 em cada tempo
dados[dados['dose'] == 'D1'].tempo.value_counts()
# Out:
# 48    4354
# 72    3907
# 24    3886
# Name: tempo, dtype: int64

# %%
# quantos foram os experimentos por tipo de tratamento, tempos de exposição e tipos de doses aplicadas
dados.groupby(['tratamento','tempo','dose']).count()['id']
# Out:
# tratamento    tempo  dose
# com_controle  24     D1       301
#                      D2       305
#               48     D1       343
#                      D2       305
#               72     D1       307
#                      D2       305
# com_droga     24     D1      3585
#                      D2      3581
#               48     D1      4011
#                      D2      3591
#               72     D1      3600
#                      D2      3580
# Name: id, dtype: int64

# %%
# Contagem do número de experimentos realizados com o composto mais aplicado categorizado por tratamento, tempo, dose
dados[dados['composto'] == '87d714366'].groupby(['tratamento', 'tempo', 'dose', 'composto']).count()['id']
# Out:
# tratamento  tempo  dose  composto
# com_droga   24     D1    87d714366    121
#                    D2    87d714366    114
#             48     D1    87d714366    131
#                    D2    87d714366    116
#             72     D1    87d714366    123
#                    D2    87d714366    113
# Name: id, dtype: int64

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')*100
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         7.745754  92.254246
#      48         7.877814  92.122186
#      72         7.857691  92.142309
# D2   24         7.848688  92.151312
#      48         7.828542  92.171458
#      72         7.850708  92.149292

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='columns')*100
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        16.130761  16.334062
#      48        18.381565  18.275014
#      72        16.452304  16.402406
# D2   24        16.345123  16.315837
#      48        16.345123  16.361400
#      72        16.345123  16.311281

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
#uso do melt

pd.melt(dados, id_vars=['tempo'], value_vars=['tratamento', 'dose'])
# Out:
#        tempo    variable      value
# 0         24  tratamento  com_droga
# 1         72  tratamento  com_droga
# 2         48  tratamento  com_droga
# 3         48  tratamento  com_droga
# 4         72  tratamento  com_droga
# ...      ...         ...        ...
# 47623     24        dose         D2
# 47624     24        dose         D2
# 47625     48        dose         D2
# 47626     24        dose         D1
# 47627     72        dose         D1
#
# [47628 rows x 3 columns]

# %%
fig, axs = plt.subplots(2, 3, figsize=(20, 20))
sns.scatterplot(x='g0',y='g8', data=dados, ax=axs[0,0])
sns.scatterplot(x='g1',y='g8', data=dados, ax=axs[0,1])
sns.scatterplot(x='g2',y='g8', data=dados, ax=axs[0,2])
sns.scatterplot(x='g3',y='g8', data=dados, ax=axs[1,0])
sns.scatterplot(x='g4',y='g8', data=dados, ax=axs[1,1])
sns.scatterplot(x='g5',y='g8', data=dados, ax=axs[1,2])

# %%
dados[{'g0','g3'}]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
# grafico de dispersão adicionando linha de tendencia
sns.lmplot(x='g0',y='g8', data=dados, line_kws={'color':'red'})

# %%
# grafico de dispersão entre g0 e g8 em diferentes cenários de tratamento e tempo
sns.lmplot(x='g0',y='g8', data=dados, line_kws={'color':'red'}, col='tratamento', row='tempo')

# %%
# Correlação de variaveis de expressão génica
dados.loc[:, 'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
# grafico de correlação entre as 50 primeiras variaveis de expressão génica
# o grafico é implementado usando um gráfico de calor heatmap

import numpy as np

corr = dados.loc[:, 'g0':'g50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

import plotly.express as px

fig = px.imshow(corr, color_continuous_scale='RdBu')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d4311c63-c77b-4036-b1d0-2b6ccdd1698e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d4311c63-c77b-4036-b1d0-2b6ccdd1698e")) {
#                     Plotly.newPlot(
#                         'd4311c63-c77b-4036-b1d0-2b6ccdd1698e',
# ...
